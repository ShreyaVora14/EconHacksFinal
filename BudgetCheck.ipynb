# %%
name=input ("Enter your name: ")
adults=int(input('Enter the number of adults (18+) in your family: '))
children=int(input('Enter the number of children (under 18) in your family: '))
people_working=int(input('Enter the number of people working in your household: '))
total_income=0
for i in range(0,people_working):
    income = int(input("Enter the annual income for Person: "))
    total_income += income
attend_school = int(input("Enter the number of people attending school in your household: "))
type_of_transportation=str(input("What is your family's usual transportation (Please enter one of the following (Please enter PERSONAL VEHICLE or PUBLIC TRANSPORTATION): "))
type_of_transportation=type_of_transportation.lower()
type_of_transportation=type_of_transportation.replace(" ", "")
loans = str(input("Do you have any loans? Please enter YES or NO: "))
loans = loans.lower()
loans = loans.replace(" ", "")
if loans == 'yes':
    total_loans = int(input("Enter the total payment for loans in a year: "))
insurance = str(input("Do you have an insurance? Please enter YES or NO: "))
insurance = insurance.lower()
insurance = insurance.replace(" ", "")
housing = str(input("Do you live on a rental property or a personal property (Please enter RENTAL or PERSONAL): "))
housing = housing.lower()
housing = housing.replace(" ", "")

# %%
#tax
cost_tax = 0
if total_income >= 1 and total_income < 9325:
    cost_tax = total_income * 0.10
if total_income < 37950 and total_income >= 9325:
    cost_tax = total_income * 0.15
    
if total_income < 91900 and total_income >= 37950:
    cost_tax = total_income * 0.25
    
if total_income < 191650 and total_income >= 91900:
    cost_tax = total_income * 0.28
    
if total_income<=416700 and total_income>=191650:
    cost_tax = total_income *0.33

# %%
#housing (rent or personal):
cost_home = 0
if housing == "rental":
    if total_income <= 15000:
        cost_home = 4105
       
    if total_income <= 29999 and total_income >= 15000:
        cost_home=4437
        
    if total_income <= 39999 and total_income >= 30000:
        cost_home = 4714
        
    if total_income <= 49999 and total_income >= 40000:
        cost_home = 5214
        
    if total_income <= 69999 and total_income >= 50000:
        cost_home = 5304
        
    if total_income <= 99999 and total_income >= 70000:
        cost_home = 5440
        
    if total_income<=149999 and total_income>=100000:
        cost_home=5548
        
    if total_income<=199999 and total_income>=150000:
        cost_home=5624
        
    if total_income>=200000:
        cost_home=5630
      

#personal   

if housing == "personal":
    if total_income < 15000:
        cost_home=2750
        
    if total_income <= 29999 and total_income >= 15000:
        cost_home=3869
        
    if total_income <= 39999 and total_income >= 30000:
        cost_home=4475
        
    if total_income <= 49999 and total_income >= 40000:
        cost_home=5353
       
    if total_income <= 69999 and total_income >= 50000:
        cost_home=7202
        
    if total_income <= 99999 and total_income >= 70000:
        cost_home=9426
        
    if total_income<=149999 and total_income>=100000:
        cost_home=12267
       
    if total_income<=199999 and total_income>=150000:
        cost_home=16884
        
    else:
        cost_home=24783

print(cost_home)
# Out:
# 5440

# %%
#education
education_cost = 0
if total_income < 15000:
    education_cost = 532
if total_income <= 29999 and total_income >= 15000:
    education_cost = 578
if total_income <= 39999 and total_income >= 30000:
    education_cost = 567
if total_income <= 49999 and total_income >= 40000:
    education_cost = 552
if total_income <= 69999 and total_income >= 50000:
    education_cost = 671
if total_income <= 99999 and total_income >= 70000:
    education_cost = 1010
if total_income<=149999 and total_income>=100000:
    education_cost = 1862
if total_income<=199999 and total_income>=150000:
    education_cost = 2791  
else:
    education_cost = 3220
education_cost = education_cost * children

# %%
#food
food_cost = 0
if total_income < 15000:
    food_cost = total_income * 0.10
if total_income <= 29999 and total_income >= 15000:
    food_cost = total_income * 0.10
if total_income <= 39999 and total_income >= 30000:
    food_cost = total_income * 0.11
if total_income <= 49999 and total_income >= 40000:
    food_cost = total_income * 0.12
if total_income <= 69999 and total_income >= 50000:
    food_cost = total_income * 0.13
if total_income <= 99999 and total_income >= 70000:
    food_cost = total_income * 0.14
if total_income<=149999 and total_income>=100000:
    food_cost = total_income * 0.15
if total_income<=199999 and total_income>=150000:
    food_cost = total_income * 0.15
else:
    food_cost = total_income * 0.15
people = adults + children
food_cost = food_cost * people

# %%
#transportation 
cost_tot = 0
if type_of_transportation == 'publictransportation':
    if total_income > 0 and total_income <= 39999:
        cost_tot = 334
    if total_income <= 69999 and total_income >= 40000:
        cost_tot = 510
    if total_income <= 99999 and total_income >= 70000:
        cost_tot = 682
    if total_income<=149999 and total_income>=100000:
        cost_tot = 1023
    if total_income<=199999 and total_income>=150000:
        cost_tot = 1421
    if total_income >= 200000:
        cost_tot = 3101
    
    
if type_of_transportation == 'personalvehicle':
    if total_income < 15000:
        cost_tot = 570
    if total_income <= 39999 and total_income >= 15000:
        cost_tot = 922
    if total_income <= 49999 and total_income >= 40000:
        cost_tot = 1177
    if total_income <= 69999 and total_income >= 50000:
        cost_tot = 1669
    if total_income <= 99999 and total_income >= 70000:
        cost_tot = 2378
    if total_income<=149999 and total_income>=100000:
        cost_tot = 2891
    if total_income<=199999 and total_income>=150000:
        cost_tot = 3671
    if total_income>= 200000:
        cost_tot = 5184

# %%
cost_loans = total_loans
cost_utilities = 1875

# %%
#insurance (home and health)

cost_insurance=0
if insurance=='yes':
    health_insurance=str(input("Do you have health insurance? (Enter 'yes' or 'no' ): "))
    health_insurance=health_insurance.lower()
    health_insurance.replace(" ","")
    health=0
    if health_insurance=='yes':
        if total_income < 15000:
            health= 1498
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income <= 29999 and total_income >= 15000:
            health= 2476
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income <= 39999 and total_income >= 30000:
            health=2707
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income <= 49999 and total_income >= 40000:
            health=2916
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income <= 69999 and total_income >= 50000:
            health=3121
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income <= 99999 and total_income >= 70000:
            health=3827
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income<=149999 and total_income>=100000:
            health=4476
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income<=199999 and total_income>=150000:
            health=5076
            health_ins=health*people
            cost_insurance+=health_ins
        
        if total_income>=200000:
            health=6654
            health_ins=health*people
            cost_insurance+=health_ins
    
    home_insurance=str(input("Do you have home insurance?: (Enter 'yes' or 'no' ):"))
    home_insurance=home_insurance.lower()
    home_insurance.replace(" ","")
    home=0
    if home_insurance=='yes':
        if total_income < 15000:
            home=758
            cost_insurance+=home
        
        if total_income <= 29999 and total_income >= 15000:
            home=1083
            cost_insurance+=home
        
        if total_income <= 39999 and total_income >= 30000:
            home=1193
            cost_insurance+=home
        
        if total_income <= 49999 and total_income >= 40000:
            home=1233
            cost_insurance+=home
        
        if total_income <= 69999 and total_income >= 50000:
            home=1577
            cost_insurance+=home
        
        if total_income <= 99999 and total_income >= 70000:
            home=1847
            cost_insurance+=home
        
        if total_income<=149999 and total_income>=100000:
            home=2441
            cost_insurance+=home
        
        if total_income<=199999 and total_income>=150000:
            home=3421
            cost_insurance+=home
        
        if total_income>=200000:
            home=4969
            cost_insurance+=home

# %%
#entertainment
cost_entertainment = 0
if total_income < 15000:
    cost_entertainment = 847
if total_income <= 29999 and total_income >= 15000:
    cost_entertainment = 1194
if total_income <= 39999 and total_income >= 30000:
    cost_entertainment = 1483
if total_income <= 49999 and total_income >= 40000:
    cost_entertainment = 1645
if total_income <= 69999 and total_income >= 50000:
    cost_entertainment = 2101
if total_income <= 99999 and total_income >= 70000:
    cost_entertainment = 2821
if total_income<=149999 and total_income>=100000:
    cost_entertainment = 3840 
if total_income<=199999 and total_income>=150000:
    cost_entertainment = 5139
else:
    cost_entertainment = 8952

# %%
cost_total= cost_tax + cost_home+ education_cost + food_cost + cost_tot + cost_loans + cost_utilities + cost_insurance + cost_entertainment
print(cost_total)
print(total_income)
# Out:
# 92366.0
# 95000

# %%
import random
savings_total= total_income-cost_total
changes = ["Cut back on your food bill! Try applying for a Food Stamp.", "If not already, optimize public Transportation or Carpool.", "Try to lower your Entertainment cost by trying some other low-cost activities", "Cut branded products from your expenses!", "Eat at home more! This is cost effective and healthier", "Refinance your home for a lower rate of mortgage!", "Sell items of no personal value on eBay!", "Unplug unused electrical devices!", "Cancel extra memerships!"]
# Out:
# 2634.0

# %%
import matplotlib.pyplot as plt
import random
expense_labels = ['Tax','Transportation','Housing', 'Education','Insurance','Food','Utilities','Entertainment', 'Loans', "Savings"]
expense_values=[cost_tax, cost_tot,cost_home, education_cost, cost_insurance,food_cost,  cost_utilities,  cost_entertainment, cost_loans, savings_total]
plt.axis("equal")
colors=['red','orange','yellow','green','blue','purple','pink','brown','grey', 'magenta']
plt.pie(expense_values,labels=expense_labels,radius=1.5,labeldistance=1.2, autopct='%0.2f%%',shadow=True,startangle= 230,colors=colors,)
plt.show()
if savings_total > 0:
        print("Congratulations! You saved: " + str(savings_total))
if savings_total <0:
    x = random.randint(0, 9)
    print(str(changes[x]))
# Out:
# Congratulations! You saved: 2634.0
